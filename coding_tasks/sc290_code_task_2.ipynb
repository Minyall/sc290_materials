# %% [markdown]
# # SC290 Assessment: Code Task 2 - Network Analysis
# This Coding Task will assess your understanding of networks as an analytical model in Python.

# %%
# If you're using Colab you will need to run this cell to ensure your environment is configured properly

# !pip uninstall networkx --yes
# !pip uninstall python-louvain --yes
# !pip uninstall community --yes
# !pip install python-louvain
# !pip install networkx

# %%
#*
# RUN THIS CELL TO CREATE THE GRAPH

import networkx as nx
import pandas as pd

table = pd.read_csv('https://raw.githubusercontent.com/Minyall/sc207_2022-23/master/code_task_datasets/GOT_1.csv')
# We use a slightly different method to make the graph from the table data
# than we use in the lab due to the different shape.
got_G = nx.from_pandas_edgelist(table, edge_attr='weight')

# %% [markdown]
# ## Section 1 of 3: Exploring a Graph (40 points total)
# This section will assess your ability to find out key information about the structure of a network.
#
# > ### About the data
# > For this section you will be using a dataset based on book one of the 'A Song of Ice and Fire' book series, 'Game of Thrones'. You do not have to know anything about Game of Thrones to complete this assessment.
# >
# >The dataset is an edgelist of character co-occurence in the book. If two character names occur within 15 words of one another they are considered to have co-occured. The weight indicates the number of times a pair of characters co-occurred.
# >
# > The data was originally made available at [Kaggle](https://www.kaggle.com/code/mmmarchetti/game-of-thrones-network-analysis/notebook/), where you can find similar datasets for 4 more books. The dataset provided here has been slightly adjusted for the assessment.

# %% [markdown]
# #### Task 1.1 (10 Points)
# - Using `got_G`, display the number of nodes in the graph.
# - Using `got_G` display the number of edges in the graph.

# %%
# Code here - add cells as necessary

# %% [markdown]
# #### Task 1.2 (10 Points)
# - Using NetworkX, calculate the degree centrality of the nodes in `got_G`. Assign the result to an appropriately named variable.
# - Sort your degree centrality results in descending order to find the top scoring characters.

# %%
# Code here - add cells as necessary

# %% [markdown]
# #### Task 1.3 (10 Points)
# If done correctly your code for 1.2 should demonstrate Eddard Stark is the character with the highest degree centrality. Read the possible answers below and select the correct one by finishing the comment below.
#
# - A: The degree centrality score tells us that Eddard was most frequently mentioned in the book.
# - B: The degree centrality score tells us that Eddard was the most powerful character in the book.
# - C: The degree centrality score tells us the proportion of other characters in the book that Eddard Stark co-occured with.

# %%
# The correct answer to the question above is option:

# %% [markdown]
# #### Task 1.4 (5 Points)
# How many components are in our graph? Write the code below to find out.

# %%
# Write your component counting code here

# %% [markdown]
# #### Task 1.5 (5 Points)
# Which of the sentences below is correct?
# - A: There are multiple components indicating seperate storylines with entire groups of characters that will never meet.
# - B: There is only 1 component indicating that every character has only one edge to another character.
# - C: There is only 1 component indicating that every character can be linked to every other character.

# %%
# The correct statement is:

# %% [markdown]
# ## Section 2 of 3: Community Detection (30 points total)
# This section tests your ability to identify communities in a network, and assess the community detection output.

# %%
#*
# RUN THIS CELL TO IMPORT THE COMMUNITY PACKAGE
import community

# %% [markdown]
# #### Task 2.1 (10 Points)
# Generate a dictionary of community assignments and assign it to the variable `communities`.

# %%
# Create your communities variable here

# %% [markdown]
# #### Task 2.2 (10 Points)
# How many unique communities are there in the network according to your assignments in `communities`?

# %%
# Write your code to identify how many unique communities are in the network.

# %% [markdown]
# #### Task 2.3 (5 Points)
# Calculate the modularity score of the community assignments.

# %%
# Write your code to calculate the modularity score here.

# %% [markdown]
# #### Task 2.4 (5 Points)
# Is this a good quality clustering? Remember Louvain modularity scores run from 0.0 -> 1.0. What is the threshold value that is considered a good score? Does your score meet the threshold?
#
# Complete the comments below.

# %%
# The threshold score for a 'good' clustering is:
# Does your score meet the threshold?:

# %% [markdown]
# ## Section 3 of 3: Filtering Graphs (30 points Total)
# This section tests your ability to filter a graph based its structure. You may want to review the information about the dataset at the top before completing these questions.
#
# #### Task 3.1 (15 points)
# Filter the graph so that you remove any characters that have co-occured with only 1 other character.
# > Optional: You may want to compare the number of nodes after filtering, with the number of nodes at the start to check it worked.

# %%
# Write your node filtering code here

# %% [markdown]
# #### Task 3.2 (15 points)
# Filter the graph so that you remove any edges between characters that have co-occured less than 5 times.
# > Optional: You may want to compare the number of edges after filtering, with the number of edges at the start to check it worked.

# %%
# Write your edge filtering code here
